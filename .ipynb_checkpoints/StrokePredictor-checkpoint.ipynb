# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# ### As you can see the mean avg glucose level is 15 points higher than the median. Data skewed right

# %%
df.stroke.value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
stroke = df.stroke == 1
non_stroke = df.stroke == 0
df[stroke].describe()
# Out:
#                  id         age  hypertension  heart_disease  \
# count    249.000000  249.000000    249.000000     249.000000
# mean   37115.068273   67.728193      0.265060       0.188755
# std    21993.344872   12.727419      0.442254       0.392102
# min      210.000000    1.320000      0.000000       0.000000
# 25%    17013.000000   59.000000      0.000000       0.000000
# 50%    36706.000000   71.000000      0.000000       0.000000
# 75%    56669.000000   78.000000      1.000000       0.000000
# max    72918.000000   82.000000      1.000000       1.000000
#
#        avg_glucose_level         bmi  stroke
# count         249.000000  209.000000   249.0
# mean          132.544739   30.471292     1.0
# std            61.921056    6.329452     0.0
# min            56.110000   16.900000     1.0
# 25%            79.790000   26.400000     1.0
# 50%           105.220000   29.700000     1.0
# 75%           196.710000   33.700000     1.0
# max           271.740000   56.600000     1.0

# %%
fig,ax = plt.subplots(figsize=(10,8))
sns.set_style('whitegrid')
sns.color_palette('tab10')

sns.histplot(df[non_stroke].avg_glucose_level,bins=10)
sns.histplot(df[stroke].avg_glucose_level,color='yellow',alpha=.7)
# Out:
# <AxesSubplot:xlabel='avg_glucose_level', ylabel='Count'>

# %%
#Check cat variables
for i in df[['gender','ever_married','work_type','Residence_type','smoking_status']]:
    print(i+':\n')
    print(df[i].value_counts())
    print()
# Out:
# gender:
#
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64
#
# ever_married:
#
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64
#
# work_type:
#
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64
#
# Residence_type:
#
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64
#
# smoking_status:
#
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %% [markdown]
# ##### Get categorical variables to numbers

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
df[['gender','ever_married','work_type','Residence_type','smoking_status']] = enc.fit_transform(df[['gender','ever_married','work_type','Residence_type','smoking_status']])
df.smoking_status.value_counts()
enc.categories_
# Out:
# [array(['Female', 'Male', 'Other'], dtype=object),
#  array(['No', 'Yes'], dtype=object),
#  array(['Govt_job', 'Never_worked', 'Private', 'Self-employed', 'children'],
#        dtype=object),
#  array(['Rural', 'Urban'], dtype=object),
#  array(['Unknown', 'formerly smoked', 'never smoked', 'smokes'],
#        dtype=object)]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Kinda funny age and married have the highest correlation

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.scatter(df[non_stroke].age,df[non_stroke].bmi,c=df[non_stroke].stroke,cmap='icefire')
plt.scatter(df[stroke].age,df[stroke].bmi)

plt.xlabel('Age')
plt.ylabel('BMI')
ax.set_ylim((5,75))
ax.set_title('BMI to Age separating out people who had strokes vs those that haven\'t')
# Out:
# Text(0.5, 1.0, "BMI to Age separating out people who had strokes vs those that haven't")

# %%
fig, ax = plt.subplots(figsize=(10,8))
married = df.ever_married == 1
non_married = df.ever_married == 0
young = []
for i,_ in df.iterrows():
    if df.iloc[i].age < 45:
        young.append(1)
    else:
        young.append(0)
df['young'] = young
ax= sns.violinplot(df[married].stroke,df[married].bmi,color='forestgreen')#,c=df[married].stroke,cmap='autumn')
sns.violinplot(df[non_married].stroke,df[non_married].bmi,color='yellow',hue=df[non_married].young,split=True)

custom_lines = [Line2D([0], [0], color=(.99, .99, .0, .99), lw=4),
                Line2D([0], [0], color=(.45, .54, .3, .99), lw=4),
                Line2D([0], [0], color=(.99, .99, .88,.99), lw=4)]

ax.legend(custom_lines, ['Married', 'Not Married- Younger than 45','Not Married- Older than 45'])

plt.xlabel('stroke')
plt.ylabel('BMI')
plt.ylim((5,75))
plt.title('BMI and marriage distribution with respect to age and stroke status')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'BMI and marriage distribution with respect to age and stroke status')

# %% [markdown]
# Non married stroke patients that are not married seem to be less frequent that married stroke patients

# %%
print('average age of stroke patient is:', df[stroke].age.mean())
print('average bmi of stroke patient is:', df[stroke].bmi.mean())
above_stroke_age = df[stroke].age.quantile(.35)
above_df = df.age > above_stroke_age
print('average bmi of patients above 35th percentile of stroke patient age is:',df[above_df].bmi.mean())
# Out:
# average age of stroke patient is: 67.72819277108434
# average bmi of stroke patient is: 30.471291866028707
# average bmi of patients above 35th percentile of stroke patient age is: 29.61761194029851

# %%
bmi = {}
stroke = {}
for i in [10,20,30,40,50,60,70,80,90]:
    dfi = df.loc[df.age < i]
    dfj = dfi.loc[dfi.age > i-10]
    print(f'average bmi of ages {i-10} - {i} is {dfj.bmi.mean()}')
    bmi[i] = dfj.bmi.mean()
    stroke[i] = dfj.stroke.mean() * 100
fig,ax = plt.subplots(figsize=(10,8))
sns.lineplot(data = bmi)
sns.lineplot(data=stroke)

custom_lines = [Line2D([0], [0], color=(.28, .37, .99, .91), lw=4),
                Line2D([0], [0], color=(.99, .75, 0.0, .99), lw=4)]

ax.legend(custom_lines, ['BMI', 'Stroke Percentage'])
plt.title('Average BMI per age group and Percentage of strokes in Age group')
# Out:
# average bmi of ages 0 - 10 is 18.869934640522875
# average bmi of ages 10 - 20 is 25.30288248337029
# average bmi of ages 20 - 30 is 28.371014492753623
# average bmi of ages 30 - 40 is 31.32439446366782
# average bmi of ages 40 - 50 is 31.562519685039376
# average bmi of ages 50 - 60 is 31.90828729281768
# average bmi of ages 60 - 70 is 30.915134099616857
# average bmi of ages 70 - 80 is 29.191295116772825
# average bmi of ages 80 - 90 is 27.988695652173917
# Text(0.5, 1.0, 'Average BMI per age group and Percentage of strokes in Age group')

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.decomposition import KernelPCA
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings("ignore")

svc = SVC(max_iter=5000)
sgd = SGDClassifier()
pca = KernelPCA()

X = df[['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status']]
y = df[['stroke']]

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=74,test_size = .22)

params_svc = {'kernel':['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],'degree': np.arange(0,5,.25),'gamma':['scale','auto'],'decision_function_shape':['ovo','ovr']}
params_sgd = {'loss':['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron','squared_loss', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive'],'penalty':['l1','l2']}

def grid_search(search,X,kernel = False):
    print('doing grid search')
    if kernel:
        kernel_train = np.dot(X,X.T)
    else:
        kernel_train = X
    print('starting pipe')
    pipe = Pipeline(steps=[
        ('impute',SimpleImputer(strategy='median')),
        ('search',search)
    ])
    pipe.fit(kernel_train,y_train)
    best = pipe['search'].best_params_
    print("done with pipe")

    return best
    
    
params_svc = {'kernel':['rbf', 'sigmoid'],'gamma':['scale','auto'],'decision_function_shape':['ovo','ovr']}
params_sgd = {'loss':['hinge', 'log', 'modified_huber', 'squared_hinge','squared_loss', 'epsilon_insensitive'],'penalty':['l1','l2']}

search_svc = GridSearchCV(svc,params_svc)
search_sgd = GridSearchCV(sgd,params_sgd)

best_ls = []
for i,search in enumerate([search_sgd,search_svc]):
    if i == 1:
        kernel = True
    else:
        kernel = False
    best_ls.append(grid_search(search,X_train,kernel))

best = best_ls[1]
best_2 = best_ls[0]

print('about to pipe for the final time')
svc = SVC(kernel=best['kernel'],gamma=best['gamma'],decision_function_shape=best['decision_function_shape'])
sgd = SGDClassifier(loss= best_2['loss'],penalty=best_2['penalty'])

pipe = Pipeline(steps=[
    ('impute',SimpleImputer(strategy='median')),
    ('pca',pca),
    ('model',svc)
    ])

pipe2 = Pipeline(steps=[
    ('impute',SimpleImputer(strategy='median')),
    ('pca',pca),
    ('model',sgd)
    ])

pipe.fit(X_train,y_train)
pipe2.fit(X_train,y_train)

pred = pipe.predict(X_test)
pred_2 = pipe2.predict(X_test)

mse = mean_squared_error(pred,y_test)
mse2 = mean_squared_error(pred_2,y_test)

print('r2 score of SVC model:', pipe.score(X_test,y_test))
print('mean squared error of SVC model:', mse)

print('\nr2 score of SGDC model:', pipe2.score(X_test,y_test))
print('mean squared error of SGDC model:', mse)
# Out:
# doing grid search
# starting pipe
# done with pipe
# about to pipe for the final time
# r2 score of SVC model: 0.96
# mean squared error of SVC model: 0.04
#
# r2 score of SGDC model: 0.9342222222222222
# mean squared error of SGDC model: 0.04
